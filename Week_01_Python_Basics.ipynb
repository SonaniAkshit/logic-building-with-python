# %% [markdown]
# # Week 01 – Python Basics
#
# Focus: variables, data types, input/output, loops, and conditionals.
#
# ---

# %% [markdown]
# ## Problem 1: Swap two variables
#
# **Swap two variables**
#
# The goal is to exchange the values of two variables without losing data. You need to think about how Python assigns values and how temporary storage or tuple unpacking works.

# %%
# write your code here

# %% [markdown]
# ## Problem 2: Take user input and display it back
#
# **Take user input and display it back**
#
# This checks your understanding of input handling and output formatting. Focus on how input is captured as a string and how it is displayed back to the user.

# %%
# write your code here

# %% [markdown]
# ## Problem 3: Check if a number is even or odd
#
# **Check if a number is even or odd**
#
# You must determine whether a number is divisible by 2. This problem tests conditionals and modulus operator usage.

# %%
# write your code here

# %% [markdown]
# ## Problem 4: Print multiplication table of a number
#
# **Print multiplication table of a number**
#
# This problem requires looping from a starting number to an ending number. You should focus on loop control and formatted output.

# %%
# write your code here

# %% [markdown]
# ## Problem 5: Find largest of three numbers
#
# **Find largest of three numbers**
#
# You need to compare three values and determine the maximum. This tests conditional logic and comparison operators.

# %%
# write your code here

# %% [markdown]
# ## Problem 6: Convert Celsius to Fahrenheit
#
# **Convert Celsius to Fahrenheit**
#
# This is a formula-based problem. The challenge is applying the correct mathematical conversion and handling numeric input.

# %%
# write your code here

# %% [markdown]
# ## Problem 7: Find factorial using loop
#
# **Find factorial using loop**
#
# Factorial involves repeated multiplication. This tests loop-based accumulation and understanding of base cases.

# %%
# write your code here

# %% [markdown]
# ## Problem 8: Count vowels in a string
#
# **Count vowels in a string**
#
# You must scan each character and check membership in a vowel set. This tests loops, strings, and condition checks.

# %%
# write your code here

# %% [markdown]
# ## Problem 9: Reverse a string
#
# **Reverse a string**
#
# This problem checks your ability to process strings sequentially. Think about building a new string by iterating in reverse order.

# %%
# write your code here

# %% [markdown]
# ## Problem 10: Check if number is palindrome
#
# **Check if number is palindrome**
#
# A palindrome reads the same forward and backward. You need to compare the original number with its reversed form.

# %%
# write your code here

# %% [markdown]
# ## Problem 11: Sum of first N natural numbers
#
# **Sum of first N natural numbers**
#
# You must compute a cumulative sum from 1 to N. This can be solved using loops or mathematical reasoning.

# %%
# write your code here

# %% [markdown]
# ## Problem 12: Create a number guessing game
#
# **Create a number guessing game**
#
# This problem combines loops, conditions, and random number generation. Focus on user interaction and loop termination conditions.

# %%
# write your code here

# %% [markdown]
# ## Problem 13: Print prime numbers between 1 and 100
#
# **Print prime numbers between 1 and 100**
#
# You need to check divisibility for each number in a range. This tests nested loops and optimization thinking.

# %%
# write your code here

# %% [markdown]
# ## Problem 14: Check leap year
#
# **Check leap year**
#
# Leap year logic depends on divisibility rules of 4, 100, and 400. This tests complex conditional branching.

# %%
# write your code here

# %% [markdown]
# ## Problem 15: Print Fibonacci series up to N terms
#
# **Print Fibonacci series up to N terms**
#
# This sequence builds numbers using previous two values. It tests variable updating inside loops.

# %%
# write your code here

# %% [markdown]
# ## Problem 16: Find GCD of two numbers
#
# **Find GCD of two numbers**
#
# You need to find the greatest number that divides both inputs. This tests loops or the Euclidean algorithm.

# %%
# write your code here

# %% [markdown]
# ## Problem 17: Find LCM of two numbers
#
# **Find LCM of two numbers**
#
# LCM is derived using GCD or by checking multiples. This problem checks number theory understanding.

# %%
# write your code here

# %% [markdown]
# ## Problem 18: Check vowel or consonant
#
# **Check vowel or consonant**
#
# You must classify a character based on membership in vowels. This tests string handling and conditionals.

# %%
# write your code here

# %% [markdown]
# ## Problem 19: Sum of digits of a number
#
# **Sum of digits of a number**
#
# You need to extract digits one by one and accumulate their sum. This tests loops and integer division.

# %%
# write your code here

# %% [markdown]
# ## Problem 20: Find second largest number in a list
#
# **Find second largest number in a list**
#
# You must track the largest and second largest values. This tests list traversal and comparison logic.

# %%
# write your code here

# %% [markdown]
# ## Problem 21: Count digits in a number
#
# **Count digits in a number**
#
# This problem involves repeatedly dividing the number until it becomes zero. It tests loop control and integer operations.

# %%
# write your code here

# %% [markdown]
# ## Problem 22: Print Armstrong numbers between 1 to 1000
#
# **Print Armstrong numbers between 1 to 1000**
#
# Armstrong numbers depend on digit powers. This tests nested loops and digit extraction logic.

# %%
# write your code here

# %% [markdown]
# ## Problem 23: Print star triangle pattern
#
# **Print star triangle pattern**
#
# This problem focuses on nested loops and pattern visualization. Correct spacing and iteration are key.

# %%
# write your code here

# %% [markdown]
# ## Problem 24: Create calculator using if-else
#
# **Create calculator using if-else**
#
# You must select operations based on user choice. This tests branching logic and arithmetic operations.

# %%
# write your code here

# %% [markdown]
# ## Problem 25: Print ASCII value of a character
#
# **Print ASCII value of a character**
#
# This checks your understanding of character encoding. You need to convert a character to its numeric representation.

# %%
# write your code here

# %% [markdown]
# ## Problem 26: Convert decimal to binary
#
# **Convert decimal to binary**
#
# This requires repeated division by 2 and remainder tracking. It tests loop logic and number base conversion.

# %%
# write your code here

# %% [markdown]
# ## Problem 27: Find square root of a number
#
# **Find square root of a number**
#
# You must compute the square root using a formula or built-in logic. Focus on numeric precision.

# %%
# write your code here

# %% [markdown]
# ## Problem 28: Sum of all even numbers in a list
#
# **Sum of all even numbers in a list**
#
# You need to iterate through a list and conditionally add values. This tests list processing.

# %%
# write your code here

# %% [markdown]
# ## Problem 29: Check if a number is prime
#
# **Check if a number is prime**
#
# Prime checking requires verifying divisibility conditions. This tests efficient loop usage.

# %%
# write your code here

# %% [markdown]
# ## Problem 30: Print cube of numbers up to N
#
# **Print cube of numbers up to N**
#
# You must loop through numbers and compute cubes. This tests arithmetic inside loops.

# %%
# write your code here
