# %% [markdown]
# # Week 03 – Files, Errors & Comprehensions
#
# Focus: file handling, error handling, modules, generators.
#
# ---

# %% [markdown]
# ## Problem 1: Read a file and print its contents
#
# **Read a file and print its contents**
#
# You need to open a file safely and read its data. Focus on file modes, reading methods, and closing the file properly.

# %%
# write your code here

# %% [markdown]
# ## Problem 2: Create a file and write your name into it
#
# **Create a file and write your name into it**
#
# This tests file writing operations. Think about write mode and what happens if the file already exists.

# %%
# write your code here

# %% [markdown]
# ## Problem 3: Handle ZeroDivisionError using try-except
#
# **Handle ZeroDivisionError using try-except**
#
# You must protect your program from crashing when division by zero occurs. This tests exception handling basics.

# %%
# write your code here

# %% [markdown]
# ## Problem 4: Handle file not found error
#
# **Handle file not found error**
#
# You need to catch errors that occur when a file does not exist. This tests defensive programming practices.

# %%
# write your code here

# %% [markdown]
# ## Problem 5: Create a module and import it into another file
#
# **Create a module and import it into another file**
#
# This checks your understanding of modular code. Focus on how Python locates and imports modules.

# %%
# write your code here

# %% [markdown]
# ## Problem 6: Filter even numbers using list comprehension
#
# **Filter even numbers using list comprehension**
#
# You need to apply conditions inside a comprehension. This tests concise logic writing.

# %%
# write your code here

# %% [markdown]
# ## Problem 7: Create a generator that yields even numbers up to N
#
# **Create a generator that yields even numbers up to N**
#
# This problem tests lazy evaluation and memory-efficient looping. Focus on yield instead of return.

# %%
# write your code here

# %% [markdown]
# ## Problem 8: Count lines and words in a file
#
# **Count lines and words in a file**
#
# You must process file content line by line. Think about string splitting and counting logic.

# %%
# write your code here

# %% [markdown]
# ## Problem 9: Read a CSV file and print its contents
#
# **Read a CSV file and print its contents**
#
# This tests structured file reading. Focus on handling delimiters and row-wise reading.

# %%
# write your code here

# %% [markdown]
# ## Problem 10: Handle multiple exceptions in a single try block
#
# **Handle multiple exceptions in a single try block**
#
# You need to anticipate different failure cases. This tests clean and readable exception handling.

# %%
# write your code here
