# %% [markdown]
# # Week 04 – Logic Building & Strings
#
# Focus: string manipulation and logical problem solving.
#
# ---

# %% [markdown]
# ## Problem 1: Check if a string has all unique characters
#
# **Check if a string has all unique characters**
#
# You must verify that no character repeats. Think about tracking seen characters and early exit conditions.

# %%
# write your code here

# %% [markdown]
# ## Problem 2: Remove duplicate characters from a string
#
# **Remove duplicate characters from a string**
#
# This problem focuses on preserving order while eliminating duplicates. Careful string reconstruction is required.

# %%
# write your code here

# %% [markdown]
# ## Problem 3: Count frequency of each character in a string
#
# **Count frequency of each character in a string**
#
# You need to map characters to counts. This tests dictionary usage and string traversal.

# %%
# write your code here

# %% [markdown]
# ## Problem 4: Count uppercase and lowercase letters in a sentence
#
# **Count uppercase and lowercase letters in a sentence**
#
# You must classify characters based on their case. Focus on character properties and conditional logic.

# %%
# write your code here

# %% [markdown]
# ## Problem 5: Find the longest word in a sentence
#
# **Find the longest word in a sentence**
#
# You need to split a sentence into words and compare lengths. This tests string splitting and comparison logic.

# %%
# write your code here

# %% [markdown]
# ## Problem 6: Reverse a string without using slicing
#
# **Reverse a string without using slicing**
#
# This problem tests manual string traversal. Think about building the reversed string step by step.

# %%
# write your code here

# %% [markdown]
# ## Problem 7: Check if a string is a pangram
#
# **Check if a string is a pangram**
#
# A pangram contains every alphabet letter at least once. You must track coverage of characters.

# %%
# write your code here

# %% [markdown]
# ## Problem 8: Sort words in a sentence alphabetically
#
# **Sort words in a sentence alphabetically**
#
# You need to split, sort, and rejoin words. This tests string manipulation and ordering.

# %%
# write your code here

# %% [markdown]
# ## Problem 9: Check if two strings are anagrams
#
# **Check if two strings are anagrams**
#
# You must compare character frequencies after normalization. This tests careful string preprocessing.

# %%
# write your code here

# %% [markdown]
# ## Problem 10: Capitalize the first letter of each word
#
# **Capitalize the first letter of each word**
#
# You must transform words individually while preserving spacing.

# %%
# write your code here

# %% [markdown]
# ## Problem 11: Extract numbers from a string and return their sum
#
# **Extract numbers from a string and return their sum**
#
# You need to detect numeric sequences inside text. This tests character classification and accumulation.

# %%
# write your code here

# %% [markdown]
# ## Problem 12: Replace all spaces with underscores
#
# **Replace all spaces with underscores**
#
# This tests basic string replacement and transformation.

# %%
# write your code here

# %% [markdown]
# ## Problem 13: Count how many times a substring appears in a string
#
# **Count how many times a substring appears in a string**
#
# You must search repeatedly without missing overlaps. This tests careful indexing logic.

# %%
# write your code here

# %% [markdown]
# ## Problem 14: Convert a string to title case without using built-in methods
#
# **Convert a string to title case without using built-in methods**
#
# You must manually control capitalization logic.

# %%
# write your code here

# %% [markdown]
# ## Problem 15: Merge two dictionaries
#
# **Merge two dictionaries**
#
# This checks dictionary combination logic and key handling.

# %%
# write your code here

# %% [markdown]
# ## Problem 16: Remove all non-alphabetic characters from a string
#
# **Remove all non-alphabetic characters from a string**
#
# You need to filter characters based on type. This tests clean text processing.

# %%
# write your code here

# %% [markdown]
# ## Problem 17: Check if a string ends with a given suffix
#
# **Check if a string ends with a given suffix**
#
# You must compare string endings safely.

# %%
# write your code here

# %% [markdown]
# ## Problem 18: Count words, characters, and lines in a paragraph
#
# **Count words, characters, and lines in a paragraph**
#
# This tests multi-metric text analysis.

# %%
# write your code here

# %% [markdown]
# ## Problem 19: Encode a string using Caesar cipher (shift = 3)
#
# **Encode a string using Caesar cipher (shift = 3)**
#
# You must shift characters while preserving case. This tests ASCII manipulation.

# %%
# write your code here

# %% [markdown]
# ## Problem 20: Count vowels and consonants in a string
#
# **Count vowels and consonants in a string**
#
# You must classify alphabetic characters accurately.

# %%
# write your code here

# %% [markdown]
# ## Problem 21: Convert binary string to decimal
#
# **Convert binary string to decimal**
#
# This tests number base conversion logic.

# %%
# write your code here

# %% [markdown]
# ## Problem 22: Count words starting with a vowel
#
# **Count words starting with a vowel**
#
# You need to analyze word boundaries and starting characters.

# %%
# write your code here

# %% [markdown]
# ## Problem 23: Remove stop words from a sentence
#
# **Remove stop words from a sentence**
#
# This tests filtering logic and list membership checks.

# %%
# write your code here

# %% [markdown]
# ## Problem 24: Reverse each word in a sentence
#
# **Reverse each word in a sentence**
#
# You must preserve word order while reversing characters.

# %%
# write your code here

# %% [markdown]
# ## Problem 25: Create a string from every third character
#
# **Create a string from every third character**
#
# This tests index stepping logic.

# %%
# write your code here

# %% [markdown]
# ## Problem 26: Find all palindromic substrings in a string
#
# **Find all palindromic substrings in a string**
#
# You must explore all substrings and test palindrome property. This is logic-heavy and requires nested loops.

# %%
# write your code here

# %% [markdown]
# ## Problem 27: Compress a string using run-length encoding
#
# **Compress a string using run-length encoding**
#
# You must count consecutive characters. This tests grouping logic.

# %%
# write your code here

# %% [markdown]
# ## Problem 28: Count frequency of each word in a file
#
# **Count frequency of each word in a file**
#
# You must combine file reading with text processing.

# %%
# write your code here

# %% [markdown]
# ## Problem 29: Extract hashtags from a tweet
#
# **Extract hashtags from a tweet**
#
# You need to detect patterns inside text. This tests string parsing logic.

# %%
# write your code here

# %% [markdown]
# ## Problem 30: Remove punctuation from a string
#
# **Remove punctuation from a string**
#
# You must clean text by filtering unwanted characters.

# %%
# write your code here

# %% [markdown]
# ## Problem 31: Find the first non-repeating character in a string
#
# **Find the first non-repeating character in a string**
#
# You need to count frequencies and preserve order.

# %%
# write your code here

# %% [markdown]
# ## Problem 32: Convert camelCase to snake_case
#
# **Convert camelCase to snake_case**
#
# You must detect uppercase boundaries and insert separators.

# %%
# write your code here

# %% [markdown]
# ## Problem 33: Generate acronyms from a sentence
#
# **Generate acronyms from a sentence**
#
# You need to extract initials from words.

# %%
# write your code here

# %% [markdown]
# ## Problem 34: Check if a file contains a specific word
#
# **Check if a file contains a specific word**
#
# You must search text safely inside a file.

# %%
# write your code here

# %% [markdown]
# ## Problem 35: Find and replace text in a file
#
# **Find and replace text in a file**
#
# This tests reading, modifying, and rewriting file content.

# %%
# write your code here

# %% [markdown]
# ## Problem 36: Check if a string contains only digits
#
# **Check if a string contains only digits**
#
# You must validate character types.

# %%
# write your code here

# %% [markdown]
# ## Problem 37: Calculate average word length in a sentence
#
# **Calculate average word length in a sentence**
#
# You must combine counting and division logic.

# %%
# write your code here

# %% [markdown]
# ## Problem 38: Remove HTML tags from a string
#
# **Remove HTML tags from a string**
#
# This tests pattern-based text cleaning.

# %%
# write your code here

# %% [markdown]
# ## Problem 39: Parse a date string and change its format
#
# **Parse a date string and change its format**
#
# You must split and rearrange date components correctly.

# %%
# write your code here

# %% [markdown]
# ## Problem 40: Extract all email addresses from text
#
# **Extract all email addresses from text**
#
# You must detect structured patterns inside text.

# %%
# write your code here

# %% [markdown]
# ## Problem 41: Count occurrence of each vowel in a paragraph
#
# **Count occurrence of each vowel in a paragraph**
#
# You must track vowel counts individually.

# %%
# write your code here

# %% [markdown]
# ## Problem 42: Validate email address format
#
# **Validate email address format**
#
# This tests format rules and string validation logic.

# %%
# write your code here

# %% [markdown]
# ## Problem 43: Check if a string is a valid URL
#
# **Check if a string is a valid URL**
#
# You must validate structure and prefixes.

# %%
# write your code here

# %% [markdown]
# ## Problem 44: Extract all integers from text
#
# **Extract all integers from text**
#
# You need to detect numeric patterns.

# %%
# write your code here

# %% [markdown]
# ## Problem 45: Find duplicate words in a paragraph
#
# **Find duplicate words in a paragraph**
#
# You must detect repeated words ignoring case.

# %%
# write your code here

# %% [markdown]
# ## Problem 46: Convert a sentence to Pig Latin
#
# **Convert a sentence to Pig Latin**
#
# This tests string transformation rules.

# %%
# write your code here

# %% [markdown]
# ## Problem 47: Find the longest sentence in a paragraph
#
# **Find the longest sentence in a paragraph**
#
# You must split sentences and compare lengths.

# %%
# write your code here

# %% [markdown]
# ## Problem 48: Display lines from a file containing a keyword
#
# **Display lines from a file containing a keyword**
#
# This tests file scanning and condition filtering.

# %%
# write your code here

# %% [markdown]
# ## Problem 49: Clean a text file by removing extra spaces and blank lines
#
# **Clean a text file by removing extra spaces and blank lines**
#
# You must normalize text formatting.

# %%
# write your code here

# %% [markdown]
# ## Problem 50: Count number of sentences in a paragraph
#
# **Count number of sentences in a paragraph**
#
# You must detect sentence-ending punctuation accurately.

# %%
# write your code here
