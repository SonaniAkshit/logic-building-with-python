# %% [markdown]
# # Week 02 – Functions & Collections
#
# Focus: functions, lists, tuples, dictionaries, and sets.
#
# ---

# %% [markdown]
# ## Problem 1: Check if a number is even using a function
#
# **Check if a number is even using a function**
#
# You need to define a function that takes a number as input and returns whether it is even. Focus on function structure, return values, and separation of logic from execution.

# %%
# write your code here

# %% [markdown]
# ## Problem 2: Find the sum of all elements in a list
#
# **Find the sum of all elements in a list**
#
# This problem tests list traversal and accumulation. Think about how to iterate through a list and maintain a running total.

# %%
# write your code here

# %% [markdown]
# ## Problem 3: Find maximum and minimum in a list
#
# **Find maximum and minimum in a list**
#
# You must scan a list and track extreme values. This checks comparison logic and understanding of list iteration.

# %%
# write your code here

# %% [markdown]
# ## Problem 4: Remove duplicates from a list
#
# **Remove duplicates from a list**
#
# You need to ensure each element appears only once. Think about how sets or manual checks can help remove repeated values.

# %%
# write your code here

# %% [markdown]
# ## Problem 5: Reverse a list using a function
#
# **Reverse a list using a function**
#
# This tests how to manipulate lists inside functions. Focus on returning a new list instead of modifying the original blindly.

# %%
# write your code here

# %% [markdown]
# ## Problem 6: Access elements of a tuple
#
# **Access elements of a tuple**
#
# This problem checks understanding of tuple indexing and immutability. You should know how tuples differ from lists.

# %%
# write your code here

# %% [markdown]
# ## Problem 7: Convert list to tuple and tuple to list
#
# **Convert list to tuple and tuple to list**
#
# This tests type conversion and understanding of Python data structures.

# %%
# write your code here

# %% [markdown]
# ## Problem 8: Merge two dictionaries
#
# **Merge two dictionaries**
#
# You must combine key-value pairs from two dictionaries. Think about what happens when keys overlap.

# %%
# write your code here

# %% [markdown]
# ## Problem 9: Count frequency of elements in a list
#
# **Count frequency of elements in a list**
#
# This requires counting how many times each element appears. Focus on dictionary usage and conditional updates.

# %%
# write your code here

# %% [markdown]
# ## Problem 10: Create a dictionary of squares from 1 to 10
#
# **Create a dictionary of squares from 1 to 10**
#
# This tests dictionary creation and looping logic. You should map numbers to their square values.

# %%
# write your code here

# %% [markdown]
# ## Problem 11: Sort a list in ascending order
#
# **Sort a list in ascending order**
#
# This checks list ordering and comparison logic. Understand both built-in sorting and manual approaches.

# %%
# write your code here

# %% [markdown]
# ## Problem 12: Check if a key exists in a dictionary
#
# **Check if a key exists in a dictionary**
#
# You must safely verify the presence of a key without causing errors.

# %%
# write your code here

# %% [markdown]
# ## Problem 13: Perform union, intersection, and difference on sets
#
# **Perform union, intersection, and difference on sets**
#
# This tests set theory operations and understanding of unique elements.

# %%
# write your code here

# %% [markdown]
# ## Problem 14: Find common elements in two lists
#
# **Find common elements in two lists**
#
# You need to compare two collections and extract shared values. Think about efficiency and clarity.

# %%
# write your code here

# %% [markdown]
# ## Problem 15: Find factorial using a function
#
# **Find factorial using a function**
#
# This tests function design and loop-based multiplication logic.

# %%
# write your code here

# %% [markdown]
# ## Problem 16: Check if a string is palindrome using a function
#
# **Check if a string is palindrome using a function**
#
# You must compare a string with its reverse. Focus on clean function logic.

# %%
# write your code here

# %% [markdown]
# ## Problem 17: Count vowels in a string using a function
#
# **Count vowels in a string using a function**
#
# This tests string traversal and condition checks inside a function.

# %%
# write your code here

# %% [markdown]
# ## Problem 18: Iterate over keys and values of a dictionary
#
# **Iterate over keys and values of a dictionary**
#
# You should understand dictionary iteration patterns and unpacking.

# %%
# write your code here

# %% [markdown]
# ## Problem 19: Remove punctuation from a string
#
# **Remove punctuation from a string**
#
# This problem focuses on text cleaning. Think about character filtering logic.

# %%
# write your code here

# %% [markdown]
# ## Problem 20: Capitalize the first letter of each word
#
# **Capitalize the first letter of each word**
#
# You must split a string into words and transform each word correctly.

# %%
# write your code here

# %% [markdown]
# ## Problem 21: Get squares of even numbers using list comprehension
#
# **Get squares of even numbers using list comprehension**
#
# This checks your understanding of compact logic expressions.

# %%
# write your code here

# %% [markdown]
# ## Problem 22: Check if a string is an anagram
#
# **Check if a string is an anagram**
#
# You must compare character frequency between strings. Focus on normalization and counting logic.

# %%
# write your code here

# %% [markdown]
# ## Problem 23: Create a nested dictionary for student records
#
# **Create a nested dictionary for student records**
#
# This tests hierarchical data representation using dictionaries.

# %%
# write your code here

# %% [markdown]
# ## Problem 24: Flatten a nested list
#
# **Flatten a nested list**
#
# You need to extract elements from inner lists. Think about loops and recursion.

# %%
# write your code here

# %% [markdown]
# ## Problem 25: Find the second highest number in a list
#
# **Find the second highest number in a list**
#
# This tests careful comparison logic and edge-case handling.

# %%
# write your code here

# %% [markdown]
# ## Problem 26: Rotate a list left by k positions
#
# **Rotate a list left by k positions**
#
# You must rearrange elements while preserving order. Index manipulation is key.

# %%
# write your code here

# %% [markdown]
# ## Problem 27: Find the missing number from 1 to N
#
# **Find the missing number from 1 to N**
#
# This tests arithmetic reasoning and list comparison.

# %%
# write your code here

# %% [markdown]
# ## Problem 28: Remove all None values from a list
#
# **Remove all None values from a list**
#
# You need to filter unwanted values safely.

# %%
# write your code here

# %% [markdown]
# ## Problem 29: Merge dictionaries and sum values for duplicate keys
#
# **Merge dictionaries and sum values for duplicate keys**
#
# This tests collision handling and numeric aggregation.

# %%
# write your code here

# %% [markdown]
# ## Problem 30: Find unique elements present in only one of two lists
#
# **Find unique elements present in only one of two lists**
#
# This problem checks set difference logic and clarity of thinking.

# %%
# write your code here
